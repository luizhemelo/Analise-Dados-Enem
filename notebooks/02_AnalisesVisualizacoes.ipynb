# %% [markdown]
# ### Observações
#
# *

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.max_rows = 500

# columns list
cols = ['CO_MUNICIPIO_ESC',
 'CO_MUNICIPIO_PROVA',
 'CO_PROVA_CH',
 'CO_PROVA_CN',
 'CO_PROVA_LC',
 'CO_PROVA_MT',
 'CO_UF_ESC',
 'CO_UF_PROVA',
 'NO_MUNICIPIO_ESC',
 'NO_MUNICIPIO_PROVA',
 'NU_ANO',
 'NU_INSCRICAO',
 'NU_NOTA_CH',
 'NU_NOTA_CN',
 'NU_NOTA_COMP1',
 'NU_NOTA_COMP2',
 'NU_NOTA_COMP3',
 'NU_NOTA_COMP4',
 'NU_NOTA_COMP5',
 'NU_NOTA_LC',
 'NU_NOTA_MT',
 'NU_NOTA_REDACAO',
 'Q001',
 'Q002',
 'Q003',
 'Q004',
 'Q005',
 'Q006',
 'Q007',
 'Q008',
 'Q009',
 'Q010',
 'Q011',
 'Q012',
 'Q013',
 'Q014',
 'Q015',
 'Q016',
 'Q017',
 'Q018',
 'Q019',
 'Q020',
 'Q021',
 'Q022',
 'Q023',
 'Q024',
 'Q025',
 'SG_UF_ESC',
 'SG_UF_PROVA',
 'TP_COR_RACA',
 'TP_DEPENDENCIA_ADM_ESC',
 'TP_ENSINO',
 'TP_ESCOLA',
 'TP_ESTADO_CIVIL',
 'TP_FAIXA_ETARIA',
 'TP_LINGUA',
 'TP_LOCALIZACAO_ESC',
 'TP_NACIONALIDADE',
 'TP_PRESENCA_CH',
 'TP_PRESENCA_CN',
 'TP_PRESENCA_LC',
 'TP_PRESENCA_MT',
 'TP_SEXO',
 'TP_SIT_FUNC_ESC',
 'TP_STATUS_REDACAO',
 'TP_ST_CONCLUSAO',
 'TX_GABARITO_CH',
 'TX_GABARITO_CN',
 'TX_GABARITO_LC',
 'TX_GABARITO_MT',
 'TX_RESPOSTAS_CH',
 'TX_RESPOSTAS_CN',
 'TX_RESPOSTAS_LC',
 'TX_RESPOSTAS_MT']

# %%
enem18 = enem22 = pd.read_csv("../../dados_enem/microdados_enem_2018/DADOS/MICRODADOS_ENEM_2018.csv", sep=';', encoding = "ISO-8859-1")[cols]
enem18.head()
# Out:
#    CO_MUNICIPIO_ESC  CO_MUNICIPIO_PROVA  CO_PROVA_CH  CO_PROVA_CN  \
# 0         1500800.0             1500800        454.0        449.0
# 1               NaN             1503200        454.0        447.0
# 2         3155603.0             3155603        453.0        449.0
# 3         1500800.0             1500800        452.0        450.0
# 4               NaN             2610905        452.0        448.0
#
#    CO_PROVA_LC  CO_PROVA_MT  CO_UF_ESC  CO_UF_PROVA    NO_MUNICIPIO_ESC  \
# 0        457.0        462.0       15.0           15          Ananindeua
# 1        457.0        459.0        NaN           15                 NaN
# 2        458.0        462.0       31.0           31  Rio Pardo de Minas
# 3        456.0        461.0       15.0           15          Ananindeua
# 4        456.0        460.0        NaN           26                 NaN
#
#    NO_MUNICIPIO_PROVA  ...  TP_STATUS_REDACAO  TP_ST_CONCLUSAO  \
# 0          Ananindeua  ...                1.0                2
# 1         Igarapé-Açu  ...                1.0                1
# 2  Rio Pardo de Minas  ...                1.0                2
# 3          Ananindeua  ...                1.0                2
# 4           Pesqueira  ...                1.0                1
#
#                                   TX_GABARITO_CH  \
# 0  CDECAABBDDECBEEDBEBBEBEDEEEBCEAEECECCDBDDCACD
# 1  CDECAABBDDECBEEDBEBBEBEDEEEBCEAEECECCDBDDCACD
# 2  ECCBBEBEDBEDBDDAEECDECBECACDEDEECDECAABBDEBCE
# 3  AEECDECBEBDCACDEDEEDBDDEBCECDECAABEDBEBBEBECC
# 4  AEECDECBEBDCACDEDEEDBDDEBCECDECAABEDBEBBEBECC
#
#                                   TX_GABARITO_CN  \
# 0  EBBEBACEDDEDDCBCCACBDDDAECAADBCEABEAEABDBCACE
# 1  BDDEDBCACEBCCACDCDDAECAADBDBCEEAEAABEBEBBACED
# 2  EBBEBACEDDEDDCBCCACBDDDAECAADBCEABEAEABDBCACE
# 3  ACEDEAEAEBECAADABBDBCEDEDDCDDABCCACBCACEBDEBB
# 4  BCACEEBBBDACEDECAADDDABDBCCACDCBCEDEDABEBEAEA
#
#                                       TX_GABARITO_LC  \
# 0  CBEDBBBDCBECADBBBECBEAECABDADACDBABCECBBEDADAB...
# 1  CBEDBBBDCBECADBBBECBEAECABDADACDBABCECBBEDADAB...
# 2  BCDEBDBCBBACDCBEAECBABADBBECECBDBBEABDADACEDEC...
# 3  BBEDCCBBDBBBEADECACEDBEADABEDBABAECCBEABDDBACD...
# 4  BBEDCCBBDBBBEADECACEDBEADABEDBABAECCBEABDDBACD...
#
#                                   TX_GABARITO_MT  \
# 0  ADCACEDDABEBBCBCADDACCCDEBBDAEEDBEXBCAEDABADA
# 1  ACEADCEBBDADAAEBBDDEDABADBEXCCCDBCAEEACBCDDAB
# 2  ADCACEDDABEBBCBCADDACCCDEBBDAEEDBEXBCAEDABADA
# 3  EBBDEECCCDACEADCBCAAEBBCBCADAEDABADDADDABDBEX
# 4  ADAEDABBCAADBEXEBBDEEADCCCCDACEDDABCBCAAEBBDD
#
#                                  TX_RESPOSTAS_CH  \
# 0  CBAEACBBADABADEDDCDABBEAEEBBDDCECBECDABADDEEA
# 1  BEDBBDBCCABDADABAEDDBAABCDACBECCEACABAEAAAEAB
# 2  ECBDABEADCECAEAEECBCBDEABCDEADCBBCDAECDDBDABC
# 3  ACADBCEBDAACCDAEBEEDBDDDBEECDACAABDAABABEBECC
# 4  AACCCEEADEEACEBBBEECCCBEBCECDDDAEAEDEEABEDECB
#
#                                  TX_RESPOSTAS_CN  \
# 0  BABDABEECDBDCBCAAAEDCEDDEADADEACABEEBABCABADC
# 1  BADEBBDBDECBADCCDCEDAEDBBEDCABEAECABCAEEAEACE
# 2  CEEEEDBDACBBDADABCCCBDBBEBCEDEAACBACEEEBEBBEE
# 3  AAEBECBAEAECEBAABADCDBDCDBAEDACBCDCDDCDEEBBEC
# 4  ADEEEEEBDCBBBBCAACCCEEEDDACCCDBDAACCACBACECDC
#
#                                      TX_RESPOSTAS_LC  \
# 0  99999BDAECEBACECBBBBEBBDABDAAAADECCCDADBCCBBAA...
# 1  CDEBB99999ABADBBBEBDEBBADCDBCBDDCECDDAECAACDAA...
# 2  ECBDB99999CBDDCEABEABDBDEEECCCDDCCCDBDBBAAECBC...
# 3  99999CBBEBDBCEDDCAAEDAEAEABEDCABBBCCDCDDDDCACE...
# 4  99999CDEDDDDBADDCBEBBBBBBDCDCBBDEEDADEDBDDDEBC...
#
#                                  TX_RESPOSTAS_MT
# 0  CCDAECBEBDAACDACABADECBDAADACBEDDAACBEABABDCD
# 1  AEECACDEECDBBEEEABBEADDAADCEAEAEDCEBCDABDADEA
# 2  BCAAACEBDCDBACADEABACCBDADADBDBCDCDABBDCBCDCB
# 3  DABDACDCD*ACCDDBBDADEABBEEADAECABADBDDA*CDAEA
# 4  ACCABCCBBDAEDDCBEEEEEDECECABBDCECCECDDABEADDA
#
# [5 rows x 74 columns]

# %%
enem18.dtypes!='object'
# Out:
# CO_MUNICIPIO_ESC           True
# CO_MUNICIPIO_PROVA         True
# CO_PROVA_CH                True
# CO_PROVA_CN                True
# CO_PROVA_LC                True
# CO_PROVA_MT                True
# CO_UF_ESC                  True
# CO_UF_PROVA                True
# NO_MUNICIPIO_ESC          False
# NO_MUNICIPIO_PROVA        False
# NU_ANO                     True
# NU_INSCRICAO               True
# NU_NOTA_CH                 True
# NU_NOTA_CN                 True
# NU_NOTA_COMP1              True
# NU_NOTA_COMP2              True
# NU_NOTA_COMP3              True
# NU_NOTA_COMP4              True
# NU_NOTA_COMP5              True
# NU_NOTA_LC                 True
# NU_NOTA_MT                 True
# NU_NOTA_REDACAO            True
# Q001                      False
# Q002                      False
# Q003                      False
# Q004                      False
# Q005                       True
# Q006                      False
# Q007                      False
# Q008                      False
# Q009                      False
# Q010                      False
# Q011                      False
# Q012                      False
# Q013                      False
# Q014                      False
# Q015                      False
# Q016                      False
# Q017                      False
# Q018                      False
# Q019                      False
# Q020                      False
# Q021                      False
# Q022                      False
# Q023                      False
# Q024                      False
# Q025                      False
# SG_UF_ESC                 False
# SG_UF_PROVA               False
# TP_COR_RACA                True
# TP_DEPENDENCIA_ADM_ESC     True
# TP_ENSINO                  True
# TP_ESCOLA                  True
# TP_ESTADO_CIVIL            True
# TP_FAIXA_ETARIA            True
# TP_LINGUA                  True
# TP_LOCALIZACAO_ESC         True
# TP_NACIONALIDADE           True
# TP_PRESENCA_CH             True
# TP_PRESENCA_CN             True
# TP_PRESENCA_LC             True
# TP_PRESENCA_MT             True
# TP_SEXO                   False
# TP_SIT_FUNC_ESC            True
# TP_STATUS_REDACAO          True
# TP_ST_CONCLUSAO            True
# TX_GABARITO_CH            False
# TX_GABARITO_CN            False
# TX_GABARITO_LC            False
# TX_GABARITO_MT            False
# TX_RESPOSTAS_CH           False
# TX_RESPOSTAS_CN           False
# TX_RESPOSTAS_LC           False
# TX_RESPOSTAS_MT           False
# dtype: bool

# %%
percent_missing = enem18.isnull().sum() * 100 / len(enem18)
percent_missing.sort_values(ascending=False)
# Out:
# CO_MUNICIPIO_ESC          73.723501
# TP_SIT_FUNC_ESC           73.723501
# CO_UF_ESC                 73.723501
# TP_LOCALIZACAO_ESC        73.723501
# NO_MUNICIPIO_ESC          73.723501
# TP_DEPENDENCIA_ADM_ESC    73.723501
# SG_UF_ESC                 73.723501
# TP_ENSINO                 36.829096
# NU_NOTA_CN                29.175297
# TX_RESPOSTAS_CN           29.175297
# TX_GABARITO_MT            29.175297
# TX_GABARITO_CN            29.175297
# NU_NOTA_MT                29.175297
# TX_RESPOSTAS_MT           29.175297
# CO_PROVA_MT               29.175297
# CO_PROVA_CN               29.175297
# NU_NOTA_COMP1             24.765127
# CO_PROVA_CH               24.765127
# NU_NOTA_COMP2             24.765127
# TX_GABARITO_CH            24.765127
# CO_PROVA_LC               24.765127
# TX_GABARITO_LC            24.765127
# TX_RESPOSTAS_CH           24.765127
# TP_STATUS_REDACAO         24.765127
# TX_RESPOSTAS_LC           24.765127
# NU_NOTA_CH                24.765127
# NU_NOTA_LC                24.765127
# NU_NOTA_COMP5             24.765127
# NU_NOTA_COMP3             24.765127
# NU_NOTA_COMP4             24.765127
# NU_NOTA_REDACAO           24.765127
# TP_ESTADO_CIVIL            3.947162
# TP_PRESENCA_LC             0.002811
# TP_PRESENCA_CH             0.002811
# TP_PRESENCA_CN             0.002811
# TP_PRESENCA_MT             0.002811
# TP_SEXO                    0.000000
# TP_NACIONALIDADE           0.000000
# CO_UF_PROVA                0.000000
# TP_LINGUA                  0.000000
# TP_FAIXA_ETARIA            0.000000
# SG_UF_PROVA                0.000000
# TP_ESCOLA                  0.000000
# NO_MUNICIPIO_PROVA         0.000000
# TP_ST_CONCLUSAO            0.000000
# NU_ANO                     0.000000
# TP_COR_RACA                0.000000
# Q023                       0.000000
# NU_INSCRICAO               0.000000
# Q025                       0.000000
# Q001                       0.000000
# Q002                       0.000000
# Q003                       0.000000
# Q004                       0.000000
# Q005                       0.000000
# Q006                       0.000000
# Q007                       0.000000
# Q008                       0.000000
# Q009                       0.000000
# Q010                       0.000000
# Q011                       0.000000
# Q012                       0.000000
# Q013                       0.000000
# Q014                       0.000000
# Q015                       0.000000
# CO_MUNICIPIO_PROVA         0.000000
# Q017                       0.000000
# Q018                       0.000000
# Q019                       0.000000
# Q020                       0.000000
# Q021                       0.000000
# Q022                       0.000000
# Q024                       0.000000
# Q016                       0.000000
# dtype: float64

# %%
plt.figure(figsize=(9, 7))
heatmap = sns.heatmap(enem18.corr(numeric_only=True), cmap="BrBG", annot=False)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12)
plt.show()
